# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\建立财务矩阵\TechNews_predict_merge_-2.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date[0])
print(finance_date[0])
#differ=set(news_date).difference(finance_date)
#print(differ)
differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]

for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)

'''
with open('./中兴新闻矩阵.csv','r',encoding='utf-8') as r:
    lines=r.readlines()
    
    #print(lines)
    with open('./中兴新闻矩阵_afterMerge.csv','w',encoding='utf-8') as w:
       for i in range(len(drop)):
            w.write(lines[drop[i]])    

'''
       
            
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# 2019/12/31
# ת¼ ����˾ Rev �� ��˽ ���� �� Ա�� �� ���� �ͻ� ����
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-01ec6cbe6370> in <module>
#      54  #   lines=r.readlines()
#      55 with open(finance_file,'r',encoding='utf-8') as r:
# ---> 56     lines=r.readlines()
#      57     #print(lines)
#      58     # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
#
# D:\Anaconda\envs\stock\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb7 in position 23: invalid start byte

# %%
#-*- coding:utf-8 -*-
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-ffe976f00c2e> in <module>
#       3  #   lines=r.readlines()
#       4 with open(finance_file,'r',encoding='utf-8') as r:
# ----> 5     lines=r.readlines()
#       6     #print(lines)
#       7     # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
#
# D:\Anaconda\envs\stock\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb7 in position 23: invalid start byte

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\合并情感维度\Bi-LSTM\code\TechNews_predict_merge_-1_new.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date[0])
print(finance_date[0])
#differ=set(news_date).difference(finance_date)
#print(differ)
differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]

for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)

'''
with open('./中兴新闻矩阵.csv','r',encoding='utf-8') as r:
    lines=r.readlines()
    
    #print(lines)
    with open('./中兴新闻矩阵_afterMerge.csv','w',encoding='utf-8') as w:
       for i in range(len(drop)):
            w.write(lines[drop[i]])    

'''
       
            
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# 2019/12/31
# 2010/2/4

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\合并情感维度\Bi-LSTM\code\TechNews_predict_merge_-1_new.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date[0])
print(finance_date[0])
#differ=set(news_date).difference(finance_date)
#print(differ)
differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]

for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)
# Out:
# 2010/2/4
# 2010/2/4
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-112100fda8c3> in <module>
#      54  #   lines=r.readlines()
#      55 with open(finance_file,'r',encoding='utf-8') as r:
# ---> 56     lines=r.readlines()
#      57     #print(lines)
#      58     # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
#
# D:\Anaconda\envs\stock\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 50-51: invalid continuation byte

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='.\Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\合并情感维度\Bi-LSTM\code\TechNews_predict_merge_-1_new1.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date)
print(finance_date)
differ=set(news_date).difference(finance_date)
#print(differ)
#differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]
for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)

'''
with open('./中兴新闻矩阵.csv','r',encoding='utf-8') as r:
    lines=r.readlines()
    
    #print(lines)
    with open('./中兴新闻矩阵_afterMerge.csv','w',encoding='utf-8') as w:
       for i in range(len(drop)):
            w.write(lines[drop[i]])    

'''
       
            
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# 0       2019/12/31
# 1       2019/12/30
# 2       2019/12/27
# 3       2019/12/26
# 4       2019/12/25
#            ...
# 1723     2010/2/25
# 1724     2010/2/24
# 1725      2010/2/9
# 1726      2010/2/5
# 1727      2010/2/4
# Name: date, Length: 1728, dtype: object
# 0        2010/2/4
# 1        2010/2/5
# 2        2010/2/9
# 3       2010/2/18
# 4       2010/2/21
#           ...
# 9420     2020/3/2
# 9421     2020/3/2
# 9422     2020/3/2
# 9423     2020/3/2
# 9424     2020/3/2
# Name: Date, Length: 9425, dtype: object
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-223d5c2a38c0> in <module>
#      53  #   lines=r.readlines()
#      54 with open(finance_file,'r',encoding='utf-8') as r:
# ---> 55     lines=r.readlines()
#      56     #print(lines)
#      57     # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
#
# D:\Anaconda\envs\stock\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 50-51: invalid continuation byte

# %%
differ
# Out:
# set()

# %%
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7724844ac755> in <module>
#       2  #   lines=r.readlines()
#       3 import sys
# ----> 4 reload(sys)
#       5 sys.setdefaultencoding('utf-8')
#       6 with open(finance_file,'r',encoding='utf-8') as r:
#
# NameError: name 'reload' is not defined

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='.\Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\合并情感维度\Bi-LSTM\code\merge合并预测结果.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date)
print(finance_date)
differ=set(news_date).difference(finance_date)
#print(differ)
#differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]
for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)

'''
with open('./中兴新闻矩阵.csv','r',encoding='utf-8') as r:
    lines=r.readlines()
    
    #print(lines)
    with open('./中兴新闻矩阵_afterMerge.csv','w',encoding='utf-8') as w:
       for i in range(len(drop)):
            w.write(lines[drop[i]])    

'''
       
            
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# 0       2019/12/31
# 1       2019/12/30
# 2       2019/12/27
# 3       2019/12/26
# 4       2019/12/25
#            ...
# 1723     2010/2/25
# 1724     2010/2/24
# 1725      2010/2/9
# 1726      2010/2/5
# 1727      2010/2/4
# Name: date, Length: 1728, dtype: object
# 0        2010/2/4
# 1        2010/2/5
# 2        2010/2/9
# 3       2010/2/18
# 4       2010/2/21
#           ...
# 9420     2020/3/2
# 9421     2020/3/2
# 9422     2020/3/2
# 9423     2020/3/2
# 9424     2020/3/2
# Name: Date, Length: 9425, dtype: object

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 26 23:07:17 2020

@author: wuzix
"""

import pandas as pd

#news_file='../建立财务矩阵/raw data/afterMerge/中兴新闻矩阵_with财务删0_afterMerge_5.csv'
#finance_file='./Zhongxing_predict_merge_-1.csv'

news_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\建立财务矩阵\合并\Zhongxing财务_删0_label0.01_forVisual_afterMerge.csv'
finance_file='F:\股票预测测试\stock-prediction-main\代码\个股走势预测\建立财务矩阵\合并\中兴新闻矩阵_3.csv'
df=pd.read_csv(news_file,error_bad_lines=False)
cf=pd.read_csv(finance_file,error_bad_lines=False)
news_date=df.iloc[:,0]
#df=pd.DataFrame(index=news_date)
finance_date=cf.iloc[:,0]

print(news_date)
print(finance_date)
differ=set(news_date).difference(finance_date)
#print(differ)
#differ=set(news_date)^set(finance_date)
#print(differ)
drop=[]
drop2=[]
drop.append(0)
drop2.append(0)
drop_date=[]
a=[]
for i in range(len(news_date)):
    if news_date[i] not in differ:
        drop.append(i+1)
for i in range(len(finance_date)):
    if finance_date[i] not in differ:
        drop2.append(i+1)

'''
with open('./中兴新闻矩阵.csv','r',encoding='utf-8') as r:
    lines=r.readlines()
    
    #print(lines)
    with open('./中兴新闻矩阵_afterMerge.csv','w',encoding='utf-8') as w:
       for i in range(len(drop)):
            w.write(lines[drop[i]])    

'''
       
            
#with open('./Zhongxing_predict_merge_-1.csv','r',encoding='utf-8') as r:
 #   lines=r.readlines()
with open(finance_file,'r',encoding='utf-8') as r:
    lines=r.readlines()
    #print(lines)
    # with open('./afterMerge/Zhongxing_predict_mergeNews-1_with财务删0_afterMerge.csv','w',encoding='utf-8') as w:
    #    for i in range(len(drop2)):
    #         w.write(lines[drop2[i]])
    with open(news_file,'w',encoding='utf-8') as w:
           for i in range(len(drop2)):
                w.write(lines[drop2[i]])
# Out:
# 0       2019/12/31
# 1       2019/12/30
# 2       2019/12/27
# 3       2019/12/26
# 4       2019/12/25
#            ...
# 1723     2010/2/25
# 1724     2010/2/24
# 1725      2010/2/9
# 1726      2010/2/5
# 1727      2010/2/4
# Name: date, Length: 1728, dtype: object
# 0        2010/2/4
# 1        2010/2/5
# 2        2010/2/9
# 3       2010/2/18
# 4       2010/2/21
#           ...
# 6408    2020/2/25
# 6409    2020/2/26
# 6410    2020/2/27
# 6411    2020/2/28
# 6412    2020/2/29
# Name: 日期, Length: 6413, dtype: object
